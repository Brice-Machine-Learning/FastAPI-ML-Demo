# %%
from src.fastapi_ml_demo.core.inference import ARTIFACT_PATH, predict
from pathlib import Path
import joblib

# Simple test to ensure artifact loads and prediction runs
value = predict([
    6.0,    # MedInc
    25.0,   # HouseAge
    6.0,    # AveRooms
    1.0,    # AveBedrms
    900,    # Population
    3.0,    # AveOccup
    34.05,  # Latitude
    -118.25 # Longitude
])

if not ARTIFACT_PATH.exists():
    raise FileNotFoundError(
        f"Model artifact not found at expected path: {ARTIFACT_PATH}"
    )

print(f"Predicted value: {value}")
print("Value is median house value in $100,000s.")
print("Artifact loaded and prediction executed successfully.")
# Out:
# Predicted value: 2.934721939377379
# Value is median house value in $100,000s.
# Artifact loaded and prediction executed successfully.
